# %% [markdown]
# #1. Import Dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\BITCOIN\Downloads\Jonathan Chandra_00000094067_D_IS388_UAS\Jonathan Chandra_00000094067_D_IS388_UAS\heart_attack_prediction_dataset.csv")

df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %% [markdown]
# #2. Data Exploration

# %%
# first five rows of a dataset
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
#last five rows of a dataset
df.tail()
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 8758         1               1        1        0  ...
# 8759         1               0        0        1  ...
# 8760         0               1        1        1  ...
# 8761         1               0        1        0  ...
# 8762         1               1        0        0  ...
#
#       Sedentary Hours Per Day  Income        BMI  Triglycerides  \
# 8758                10.806373  235420  19.655895             67
# 8759                 3.833038  217881  23.993866            617
# ...

# %%
# print infow and describe of a data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
# it will show statistical summary of the data

df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
#shape of a data [ number of rows and columns of the data]

df.shape
# Out:
# (8763, 26)

# %%
# it will provide all the list of the columns in the data set

df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %% [markdown]
# #3. Mengecek Data Duplikat dan Data null = Data Preparation

# %%
# Checking for duplicate row

df.duplicated().sum()
# Out:
# 0

# %%
missing_values = df.isnull().sum()
missing_percentages = (df.isnull().sum() / len(df)) * 100

# %%
print("\nMissing Data Summary:")
missing_info = pd.DataFrame({
    'Missing Values': missing_values,
    'Missing Percentage': missing_percentages
})
print(missing_info)
# Out:
# Missing Data Summary:
#                                  Missing Values  Missing Percentage
# Patient ID                                    0                 0.0
# Age                                           0                 0.0
# Sex                                           0                 0.0
# Cholesterol                                   0                 0.0
# Blood Pressure                                0                 0.0
# Heart Rate                                    0                 0.0
# Diabetes                                      0                 0.0
# Family History                                0                 0.0
# Smoking                                       0                 0.0
# Obesity                                       0                 0.0
# Alcohol Consumption                           0                 0.0
# Exercise Hours Per Week                       0                 0.0
# ...

# %%
# Checking  for null values


df.isnull()   # this will retrurn boolean based data.. so we need to sum to get exaxt values of null values..

df.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
# Print original DataFrame
print("Original DataFrame:")
print(df.head())

df=df.rename(columns={
    "Sleep Hours Per Day":"Sleeping Hours",
    "Physical Activity Days Per Week":"Activity Per Week",
    "Sedentary Hours Per Day":"Sedentary Hours",
    "Patient ID":"ID"

})


# Print DataFrame after renaming
print("\nDataFrame after renaming:")
print(df.head())
# Out:
# Original DataFrame:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
# ...

# %%
df
# Out:
#            ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0     BMW7812   67    Male          208         158/88          72         0
# 1     CZE1114   21    Male          389         165/93          98         1
# 2     BNI9906   21  Female          324         174/99          72         1
# 3     JLN3497   84    Male          383        163/100          73         1
# 4     GFO8847   66    Male          318          91/88          93         1
# ...       ...  ...     ...          ...            ...         ...       ...
# 8758  MSV9918   60    Male          121          94/76          61         1
# 8759  QSV6764   28  Female          120        157/102          73         1
# 8760  XKA5925   47    Male          250         161/75         105         0
# 8761  EPE6801   36    Male          178         119/67          60         1
# 8762  ZWN9666   25  Female          356         138/67          75         1
#
# ...

# %% [markdown]
# #4. Memulai menghitung jumlah variable untuk melakukan Data Visualization

# %%
# Total number of people in every continent


People_in_COntinent=df["Continent"].value_counts()
People_in_COntinent
# Out:
# Continent
# Asia             2543
# Europe           2241
# South America    1362
# Australia         884
# Africa            873
# North America     860
# Name: count, dtype: int64

# %%
#Total number of male and female
gender_count=df["Sex"].value_counts()
gender_count
# Out:
# Sex
# Male      6111
# Female    2652
# Name: count, dtype: int64

# %%
smoking_counts=df["Smoking"].value_counts()
smoking_counts
# Out:
# Smoking
# 1    7859
# 0     904
# Name: count, dtype: int64

# %%
#  Heart attack risk

heart_risk=df["Heart Attack Risk"].value_counts()
heart_risk
# Out:
# Heart Attack Risk
# 0    5624
# 1    3139
# Name: count, dtype: int64

# %%
#subst and slice the dataset

df.iloc[:10, :5]
# Out:
#         ID  Age     Sex  Cholesterol Blood Pressure
# 0  BMW7812   67    Male          208         158/88
# 1  CZE1114   21    Male          389         165/93
# 2  BNI9906   21  Female          324         174/99
# 3  JLN3497   84    Male          383        163/100
# 4  GFO8847   66    Male          318          91/88
# 5  ZOO7941   54  Female          297         172/86
# 6  WYV0966   90    Male          358         102/73
# 7  XXM0972   84    Male          220         131/68
# 8  XCQ5937   20    Male          145        144/105
# 9  FTJ5456   43  Female          248         160/70

# %%
#  Only these of three columns

df[["Age","Continent","Heart Attack Risk"]]
# Out:
#       Age      Continent  Heart Attack Risk
# 0      67  South America                  0
# 1      21  North America                  0
# 2      21         Europe                  0
# 3      84  North America                  0
# 4      66           Asia                  0
# ...   ...            ...                ...
# 8758   60           Asia                  0
# 8759   28  North America                  0
# 8760   47  South America                  1
# 8761   36  South America                  0
# 8762   25         Europe                  1
#
# [8763 rows x 3 columns]

# %% [markdown]
# #5. Mendrop Kolom ID dalam tabel atau Patient ID untuk Data Preparation Machine Learning dan Data Preparation untuk Visualisasi Heatmap dan Visualisasi Data Korelasi mengubah Data Katogorikal

# %%
#   Drop the 'ID' column bacuse it is not nessary in our data preprocessing and ML model traing

df.drop('ID',axis=1)
# Out:
#       Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0      67    Male          208         158/88          72         0
# 1      21    Male          389         165/93          98         1
# 2      21  Female          324         174/99          72         1
# 3      84    Male          383        163/100          73         1
# 4      66    Male          318          91/88          93         1
# ...   ...     ...          ...            ...         ...       ...
# 8758   60    Male          121          94/76          61         1
# 8759   28  Female          120        157/102          73         1
# 8760   47    Male          250         161/75         105         0
# 8761   36    Male          178         119/67          60         1
# 8762   25  Female          356         138/67          75         1
#
#       Family History  Smoking  Obesity  Alcohol Consumption  ...  \
# 0                  0        1        0                    0  ...
# ...

# %%
#  Create a new column named
df["Active Hours"]=(24-df["Sedentary Hours"])

# %%
#  Now cheack that wheather the new column is created or not

df["Active Hours"]
# Out:
# 0       17.384999
# 1       19.036541
# 2       14.536574
# 3       16.351019
# 4       22.485179
#           ...
# 8758    13.193627
# 8759    20.166962
# 8760    21.624786
# 8761    23.970896
# 8762    14.994766
# Name: Active Hours, Length: 8763, dtype: float64

# %%
df['Heart Risk Score'] = (
    (df['Cholesterol'] > 200).astype(int) +
    df['Diabetes'] +
    df['Family History'] +
    df['Smoking'] +
    (df['BMI'] > 30).astype(int) +
    (df['Stress Level'] > 7).astype(int)
)

# Add a new column for Risk Score (simplified for visualization)
df['Risk Score'] = (
    df['Smoking'] +
    df['Obesity'] +
    (df['Alcohol Consumption'] > 8).astype(int) +
    (df['Sedentary Hours'] > 8).astype(int) +
    (df['Diet'] == 'Unhealthy').astype(int)
)

# %%
import seaborn as sns

# %%
from sqlalchemy import column


bmi_visualise_cases = df
age_groups = bmi_visualise_cases["Age"].value_counts().sort_index()

plt.figure(figsize=(30, 6))
sns.barplot(x="Age", y="BMI", data=bmi_visualise_cases, palette="viridis")
plt.xlabel("Age")
plt.ylabel("BMI")
plt.title("Relationship between Age and BMI")
plt.show()
# Out:
# C:\Users\BITCOIN\AppData\Local\Temp\ipykernel_28292\2213770779.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Age", y="BMI", data=bmi_visualise_cases, palette="viridis")

# %% [markdown]
# #6. Memulai Data Visualization dalam membandingkan benua yang memiliki korban terbanyak dalam risk heart attack serta merepresentasikan Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Filter hanya data dengan risiko serangan jantung (Heart Attack Risk = 1)
heart_attack_cases = df[df["Heart Attack Risk"] == 1]

# Menghitung jumlah kasus per benua
continent_counts = heart_attack_cases["Continent"].value_counts().head(7)

# Membuat visualisasi
plt.figure(figsize=(10, 6))
continent_counts.plot(kind="bar", color="skyblue", alpha=0.9)
plt.title("Top 7 Benua dengan Kasus Serangan Jantung", fontsize=14)
plt.xlabel("Benua", fontsize=12)
plt.ylabel("Jumlah Kasus", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
# Filter hanya data dengan risiko serangan jantung (Heart Attack Risk = 1)
heart_attack_cases = df[df["Heart Attack Risk"] == 1]

# Menghitung jumlah kasus per benua
continent_counts = heart_attack_cases["Country"].value_counts().head(10)

# Membuat visualisasi
plt.figure(figsize=(10, 6))
continent_counts.plot(kind="bar", color="skyblue", alpha=0.9)
plt.title("Top 10 Negara dengan Kasus Serangan Jantung", fontsize=14)
plt.xlabel("Benua", fontsize=12)
plt.ylabel("Jumlah Kasus", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
columns
# Out:
# ['Sex', 'Diet', 'Country', 'Continent', 'Hemisphere']

# %%
# First chose the columns from dataset to make a count plot

columns=["Sex","Diet","Country","Continent","Hemisphere"]
# using for loop
for column in columns:
    plt.figure(figsize=(10,3))
    sns.countplot(x=column, data=df)# X axix is represnt columns and y axis is represent data
    # title of plot
    plt.title(f"Count plot of {column}")
    plt.xticks(rotation=90)
    plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
# Impact of Smoking on Risk Score
sns.barplot(data=df, x='Smoking', y='Lifestyle Risk Score', ci=None, palette='Set2', ax=axes[0])
axes[0].set_title('Impact of Smoking on Risk Score')
axes[0].set_xlabel('Smoking (0 = No, 1 = Yes)')
axes[0].set_ylabel('Bad Lifestyle Score')

# Impact of Obesity on Risk Score
sns.barplot(data=df, x='Obesity', y='Lifestyle Risk Score', ci=None, palette='Set2', ax=axes[1])
axes[1].set_title('Impact of Obesity on Risk Score')
axes[1].set_xlabel('Obesity (0 = No, 1 = Yes)')
axes[1].set_ylabel('')
# Out:
# <ipython-input-35-d7af972086ca>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Smoking', y='Lifestyle Risk Score', ci=None, palette='Set2', ax=axes[0])
# <ipython-input-35-d7af972086ca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Smoking', y='Lifestyle Risk Score', ci=None, palette='Set2', ax=axes[0])
# <ipython-input-35-d7af972086ca>:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Obesity', y='Lifestyle Risk Score', ci=None, palette='Set2', ax=axes[1])
# <ipython-input-35-d7af972086ca>:9: FutureWarning:
#
# ...

# %%
df.tail()
# Out:
#            ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 8758  MSV9918   60    Male          121          94/76          61         1
# 8759  QSV6764   28  Female          120        157/102          73         1
# 8760  XKA5925   47    Male          250         161/75         105         0
# 8761  EPE6801   36    Male          178         119/67          60         1
# 8762  ZWN9666   25  Female          356         138/67          75         1
#
#       Family History  Smoking  Obesity  ...  Triglycerides  Activity Per Week  \
# 8758               1        1        0  ...             67                  7
# 8759               0        0        1  ...            617                  4
# 8760               1        1        1  ...            527                  4
# 8761               0        1        0  ...            114                  2
# 8762               1        0        0  ...            180                  7
#
# ...

# %%
# Line Plot hubungan usia dengan skor risiko
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="Age", y="Health Risk Score", marker="o", linestyle="--")
plt.title("Hubungan Usia dengan Skor Risiko Serangan Jantung")
plt.xlabel("Usia")
plt.ylabel("Skor Risiko Serangan Jantung")
plt.show()

# %%
# Chose the columns for pie plot

columns=["Heart Attack Risk","Smoking","Diabetes","Previous Heart Problems"]
#use for loop
for column in columns:
    plt.figure(figsize=(4,3))
    #counts the value of data
    counts=df[column].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
    plt.title(f"pie plot of {column}")
    plt.show()

# %%
# Histogram: Distribusi Skor Gaya Hidup Buruk dengan Riwayat Serangan Jantung
plt.figure(figsize=(12, 6))
sns.histplot(
    data=df,
    x="Lifestyle Risk Score",
    hue="Previous Heart Problems",
    kde=True,
    palette="coolwarm",
    bins=10,
    alpha=0.7
)
plt.title("Distribusi Skor Gaya Hidup Buruk dengan Riwayat Serangan Jantung")
plt.xlabel("Skor Gaya Hidup Buruk")
plt.ylabel("Jumlah Individu")
plt.legend(title="Riwayat Serangan Jantung", labels=["Tidak", "Ya"])
plt.show()

# %%
# Barplot untuk rata-rata BMI berdasarkan skor risiko
plt.figure(figsize=(10, 6))
sns.barplot(x="Health Risk Score", y="BMI", data=df, ci=None, palette="mako")
plt.title("Average BMI by Heart Risk Score")
plt.xlabel("Heart Risk Score")
plt.ylabel("Average BMI")
plt.show()
# Out:
# <ipython-input-41-6aecc0d7d1d7>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Health Risk Score", y="BMI", data=df, ci=None, palette="mako")
# <ipython-input-41-6aecc0d7d1d7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Health Risk Score", y="BMI", data=df, ci=None, palette="mako")

# %%
#Select the numericl columns from dataframe and store them into a new veriable

new_column=df.select_dtypes(["number"])
new_column
# Out:
#       Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0      67          208          72         0               0        1
# 1      21          389          98         1               1        1
# 2      21          324          72         1               0        0
# 3      84          383          73         1               1        1
# 4      66          318          93         1               1        1
# ...   ...          ...         ...       ...             ...      ...
# 8758   60          121          61         1               1        1
# 8759   28          120          73         1               0        0
# 8760   47          250         105         0               1        1
# 8761   36          178          60         1               0        1
# 8762   25          356          75         1               1        0
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# 0           0                    0                 4.168189
# ...

# %%
# Delet the heart attcak risk from new created data
del new_column["Heart Attack Risk"]
new_column
# Out:
#       Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0      67          208          72         0               0        1
# 1      21          389          98         1               1        1
# 2      21          324          72         1               0        0
# 3      84          383          73         1               1        1
# 4      66          318          93         1               1        1
# ...   ...          ...         ...       ...             ...      ...
# 8758   60          121          61         1               1        1
# 8759   28          120          73         1               0        0
# 8760   47          250         105         0               1        1
# 8761   36          178          60         1               0        1
# 8762   25          356          75         1               1        0
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# 0           0                    0                 4.168189
# ...

# %%
# Use the corrwith function to calculate the correlation of old data with columns of Heart attack risk

new_column.corrwith(df["Heart Attack Risk"])
# Out:
# Age                        0.006403
# Cholesterol                0.019340
# Heart Rate                -0.004251
# Diabetes                   0.017225
# Family History            -0.001652
# Smoking                   -0.004051
# Obesity                   -0.013318
# Alcohol Consumption       -0.013778
# Exercise Hours Per Week    0.011133
# Previous Heart Problems    0.000274
# Medication Use             0.002234
# Stress Level              -0.004111
# Sedentary Hours           -0.005613
# Income                     0.009628
# BMI                        0.000020
# Triglycerides              0.010471
# Activity Per Week         -0.005014
# Sleeping Hours            -0.018528
# Active Hours               0.005613
# Health Risk Score          0.006953
# Lifestyle Risk Score      -0.009457
# dtype: float64

# %%
score = new_column.corrwith(df["Heart Attack Risk"])
score
# Out:
# Age                        0.006403
# Cholesterol                0.019340
# Heart Rate                -0.004251
# Diabetes                   0.017225
# Family History            -0.001652
# Smoking                   -0.004051
# Obesity                   -0.013318
# Alcohol Consumption       -0.013778
# Exercise Hours Per Week    0.011133
# Previous Heart Problems    0.000274
# Medication Use             0.002234
# Stress Level              -0.004111
# Sedentary Hours           -0.005613
# Income                     0.009628
# BMI                        0.000020
# Triglycerides              0.010471
# Activity Per Week         -0.005014
# Sleeping Hours            -0.018528
# Active Hours               0.005613
# Health Risk Score          0.006953
# Lifestyle Risk Score      -0.009457
# dtype: float64

# %%
#   Histogram of following columns¶
#   Income,BMI,Age

columns=["Income","BMI","Age"]
for column in columns:
    plt.figure(figsize=(4,3))
    plt.hist(df[column], color="green", edgecolor='black',alpha=0.3)
    plt.title(f"Histogram{column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.xticks(rotation=91)
    plt.show()

# %% [markdown]
# #7. Membuat Sebuah Korelasi dalam Data yang mempunyai hubungan paling banyak

# %%
# Make a correlation graph to check yhe dependecy of heart attack risk with other columns

#  select a numeric columns to check the correlation of heart attack columns


numeric_cul=df.select_dtypes("number")
corr_score=numeric_cul.corr()#for correlation
corr_score
# Out:
#                               Age  Cholesterol  Heart Rate  Diabetes  \
# Age                      1.000000    -0.009107   -0.003844 -0.014105
# Cholesterol             -0.009107     1.000000    0.000315 -0.013428
# Heart Rate              -0.003844     0.000315    1.000000  0.006764
# Diabetes                -0.014105    -0.013428    0.006764  1.000000
# Family History           0.008353    -0.021608   -0.013470 -0.013844
# Smoking                  0.394891     0.016342   -0.012331  0.000527
# Obesity                 -0.008140    -0.014843    0.012725  0.012866
# Alcohol Consumption     -0.006666    -0.007261    0.003459  0.005551
# Exercise Hours Per Week  0.001206     0.021517    0.008276 -0.007014
# Previous Heart Problems  0.000868    -0.006070   -0.004956  0.000867
# Medication Use           0.000980    -0.000905    0.009244 -0.002656
# Stress Level             0.018307    -0.024487   -0.004547  0.006719
# Sedentary Hours          0.017280     0.018914   -0.010232  0.004705
# ...

# %% [markdown]
# #8. Visualisasi Corelasi Menggunakan Heatmap dalam Menganalisis Faktor Gaya Hidup dalam Resiko Serangan Jantung

# %%
# Visualize the correlation heatmap for relevant columns
plt.figure(figsize=(10, 6))
correlation_columns = ['Cholesterol', 'Heart Rate', 'Diabetes', 'Smoking', 'Obesity', 'Alcohol Consumption', 'Exercise Hours Per Week', 'Stress Level', 'BMI', 'Triglycerides', 'Risk Score']
correlation_matrix = df[correlation_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='plasma')
plt.title('Correlation Heatmap: Lifestyle Factors and Risk Score')
plt.show()

# %%
category_col=df.select_dtypes("category").columns
category_col
# Out:
# Index([], dtype='object')

# %%
bp_split=df["Blood Pressure"].str.split("/", expand=True)

bp_split
# Out:
#         0    1
# 0     158   88
# 1     165   93
# 2     174   99
# 3     163  100
# 4      91   88
# ...   ...  ...
# 8758   94   76
# 8759  157  102
# 8760  161   75
# 8761  119   67
# 8762  138   67
#
# [8763 rows x 2 columns]

# %% [markdown]
# #9. Memisahkan Kode nilai Tekanan Darah dan Mencetak nilai unik pada kolom "Diet"

# %%
df["systolic"]=bp_split[0]
df["dysystolic"]=bp_split[1]
#Convert dtpes into int
df["systolic"]=df["systolic"].astype("int32")
df["dysystolic"]=df["dysystolic"].astype("int32")
print(df["systolic"].dtype)
print(df["dysystolic"].dtype)
# Out:
# int32
# int32

# %%
print(df["Diet"].unique())
print()
# Out:
# ['Average' 'Unhealthy' 'Healthy']

# %% [markdown]
# #10. Mengetahui tingkatan dalam kondisi Heart Attack ada dalam Average, Unhealthy, Healthy

# %%
value_map={
    "Average":1,
    "Unhealthy":2,
    "Healthy":3
}

# %%
df["Diet"]=df["Diet"].map(value_map)

# %%
print(df["Diet"].unique())
df["Diet"]=df["Diet"].astype("int32")
# Out:
# [1 2 3]

# %%
df=pd.get_dummies(df, columns=["Sex","Country","Continent","Hemisphere"],drop_first=True)

# %%
df
# Out:
#            ID  Age  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0     BMW7812   67          208         158/88          72         0
# 1     CZE1114   21          389         165/93          98         1
# 2     BNI9906   21          324         174/99          72         1
# 3     JLN3497   84          383        163/100          73         1
# 4     GFO8847   66          318          91/88          93         1
# ...       ...  ...          ...            ...         ...       ...
# 8758  MSV9918   60          121          94/76          61         1
# 8759  QSV6764   28          120        157/102          73         1
# 8760  XKA5925   47          250         161/75         105         0
# 8761  EPE6801   36          178         119/67          60         1
# 8762  ZWN9666   25          356         138/67          75         1
#
#       Family History  Smoking  Obesity  Alcohol Consumption  ...  \
# 0                  0        1        0                    0  ...
# ...

# %%
bool_columns=df.select_dtypes(include="bool").columns

# %%
for bool_col in bool_columns:
    df[bool_col]=df[bool_col].astype("int32")

# %%
df.dtypes
# Out:
# ID                                 object
# Age                                 int64
# Cholesterol                         int64
# Blood Pressure                     object
# Heart Rate                          int64
# Diabetes                            int64
# Family History                      int64
# Smoking                             int64
# Obesity                             int64
# Alcohol Consumption                 int64
# Exercise Hours Per Week           float64
# Diet                                int32
# Previous Heart Problems             int64
# Medication Use                      int64
# Stress Level                        int64
# Sedentary Hours                   float64
# Income                              int64
# BMI                               float64
# Triglycerides                       int64
# Activity Per Week                   int64
# Sleeping Hours                      int64
# Heart Attack Risk                   int64
# ...

# %% [markdown]
# #11. Menghilangkan kolom ID dan Blood Pressure untuk preparasi dalam Data saat Machine model dan mengubah tipe data

# %%
del df['ID']  # delete the catagorical values

# %%
del df['Blood Pressure']

# %%
# Memory consumed by each column of the data in the systen[ as data required memory to be stoed in the ststem]

memory_usage_per_column=df.memory_usage()
single_col_memory = memory_usage_per_column   # memory consumed by single column in the memeory

# we can also add up the memory of all the columns

print('The memory in bytes is : ', single_col_memory.sum())  # memory consumed by all the column in the memeory [in bytes]

# but this memory


memory_in_KB = (single_col_memory.sum())/1024

print(memory_in_KB)
# Out:
# The memory in bytes is :  2558924
# 2498.94921875

# %%
for column in columns:
    if df[column].dtype=="int32":
        df[column]=df[column].astype("int16")
    elif df[column].dtype=="float64":
        df[column]=df[column].astype("float16")
    elif df[column].dtype=="object":
        df[column]=df[column].astype("category")

# %%
#  now cheak again the memory


memory_per_column=df.memory_usage()
memory_per_column.sum()
# Out:
# 2506346

# %%
print('Memory before chaning datatype : ',single_col_memory.sum())



print('The memory after chsnging datatyos : ',memory_per_column.sum())
# Out:
# Memory before chaning datatype :  2558924
# The memory after chsnging datatyos :  2506346

# %%
x=df.drop("Heart Attack Risk", axis=1)
y=df["Heart Attack Risk"]

# %%
X=df.drop("Heart Attack Risk", axis=1)
Y=df["Heart Attack Risk"]

# %%
df.dtypes
# Out:
# Age                                 int64
# Cholesterol                         int64
# Heart Rate                          int64
# Diabetes                            int64
# Family History                      int64
# Smoking                             int64
# Obesity                             int64
# Alcohol Consumption                 int64
# Exercise Hours Per Week           float64
# Diet                                int32
# Previous Heart Problems             int64
# Medication Use                      int64
# Stress Level                        int64
# Sedentary Hours                   float64
# Income                              int64
# BMI                               float16
# Triglycerides                       int64
# Activity Per Week                   int64
# Sleeping Hours                      int64
# Heart Attack Risk                   int64
# Active Hours                      float64
# Health Risk Score                   int64
# ...

# %% [markdown]
# #12. Memisahkan Data Train dan Test

# %%
# Split the data into train and test
from sklearn.model_selection import train_test_split

x_train,y_test,y_train,y_test=train_test_split(x,y, test_size=0.2)

# %%
df
# Out:
#       Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0      67          208          72         0               0        1
# 1      21          389          98         1               1        1
# 2      21          324          72         1               0        0
# 3      84          383          73         1               1        1
# 4      66          318          93         1               1        1
# ...   ...          ...         ...       ...             ...      ...
# 8758   60          121          61         1               1        1
# 8759   28          120          73         1               0        0
# 8760   47          250         105         0               1        1
# 8761   36          178          60         1               0        1
# 8762   25          356          75         1               1        0
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  Diet  ...  \
# ...

# %%
nunique_10=df.nunique()>10

# %%
cols_to_scale=df.loc[:, nunique_10].columns
print(cols_to_scale)
# Out:
# Index(['Age', 'Cholesterol', 'Heart Rate', 'Exercise Hours Per Week',
#        'Sedentary Hours', 'Income', 'BMI', 'Triglycerides', 'Active Hours',
#        'systolic', 'dysystolic'],
#       dtype='object')

# %%
# Chect the average of value counts in imbalce i data
y.value_counts(normalize=True)*100
# Out:
# Heart Attack Risk
# 0    64.178934
# 1    35.821066
# Name: proportion, dtype: float64

# %%
# use the Smoth in which classes has equel representation

from imblearn.over_sampling import SMOTE
smote=SMOTE(random_state=365)
x_smote,y_smote=smote.fit_resample(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
#Chect the values counts of y smote

y_smote.value_counts(normalize=True)
# Out:
# Heart Attack Risk
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
# Again split the data on y smote and x smote

x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote, test_size=0.2)

# %% [markdown]
# #13. Mengimplementasi sebuah Rabust Scaler yang akan membantu dalam proses Machine Learning

# %%
# scale the vaues of cols usin Rabust Scaler

from sklearn.preprocessing import RobustScaler
scaler=RobustScaler()
scaler.fit(x_train[cols_to_scale])
x_train[cols_to_scale]=scaler.transform(x_train[cols_to_scale])
x_test[cols_to_scale]=scaler.transform(x_test[cols_to_scale])

# %% [markdown]
# #14. Melakukan Machine Learning model dalam Mengklasifikasi Data dalam semua Data

# %%
# Import the modules
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
#train gussain Model
clf=GaussianNB()
clf.fit(x_train,y_train)
clf_score=clf.score(x_test,y_test)
print(clf_score)
# Out:
# 0.6742222222222222

# %%
# Logistic Regression
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)
print(accuracy_score(y_test, y_pred_lr))
# Out:
# 0.7004444444444444

# %%
# Get prediction from these model
#store the key valuies of models
models=[clf,lr]
model_prediction={}
for model in models:
    model_name=str(model).split("(")[0]
    model_prediction[model_name]=model.predict(x_test)
    print(model_prediction)
# Out:
# {'GaussianNB': array([0, 0, 1, ..., 0, 0, 0])}
# {'GaussianNB': array([0, 0, 1, ..., 0, 0, 0]), 'LogisticRegression': array([0, 0, 1, ..., 0, 0, 0])}

# %%
logreg = LogisticRegression(max_iter=10000, random_state=42)
logreg.fit(x_train, y_train)

y_pred_logreg = logreg.predict(x_test)

print("\nLogistic Regression Report:")
print(classification_report(y_test, y_pred_logreg))

print("Accuracy:", accuracy_score(y_test, y_pred_logreg))

print("=================================================================================================================================")
print("=================================================================================================================================")

plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred_logreg)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Logistic Regression Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.99      0.77      1123
#            1       0.98      0.41      0.58      1127
#
#     accuracy                           0.70      2250
#    macro avg       0.80      0.70      0.67      2250
# weighted avg       0.80      0.70      0.67      2250
#
# Accuracy: 0.7004444444444444
# ...

# %%
g = GaussianNB()
g.fit(x_train, y_train)

y_pred_g = g.predict(x_test)

print("\nNaye base Classifier:")
print(classification_report(y_test, y_pred_g))

print("Accuracy:", accuracy_score(y_test, y_pred_g))

print("=================================================================================================================================")
print("=================================================================================================================================")

plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred_g)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Naye base Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Naye base Classifier:
#               precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71      1123
#            1       0.74      0.54      0.63      1127
#
#     accuracy                           0.67      2250
#    macro avg       0.69      0.67      0.67      2250
# weighted avg       0.69      0.67      0.67      2250
#
# Accuracy: 0.6742222222222222
# ...

# %% [markdown]
# #15. Semua Hasil Dalam Evaluasi

# %%
print("\n=== Model Comparison Semua Data===")
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_logreg))
print("Naye base Classifier:", accuracy_score(y_test, y_pred_g))
# Out:
# === Model Comparison Semua Data===
# Logistic Regression Accuracy: 0.7004444444444444
# Naye base Classifier: 0.6742222222222222

# %%
# Evaluate the perforamnce model
from sklearn.metrics import accuracy_score,\
                                           f1_score, precision_score,recall_score

model_evaluation={}
for model, preds in model_prediction.items():
    model_evaluation[model]=[
        round(accuracy_score(y_test,preds)*100,2),
        round(f1_score(y_test,preds)*100,2),
        round(precision_score(y_test,preds)*100,2),
        round(recall_score(y_test,preds)*100,2),
    ]

# %%
#Get the results
results_df=pd.DataFrame(model_evaluation, index=["Accuracy","F1 Score","Precision","recall"])
results_df.style.background_gradient(axis=None, cmap="bone")
# Out:
# <style type="text/css">
# #T_b157e_row0_col0 {
#   background-color: #676f87;
#   color: #f1f1f1;
# }
# #T_b157e_row0_col1 {
#   background-color: #717d91;
#   color: #f1f1f1;
# }
# #T_b157e_row1_col0 {
#   background-color: #545574;
#   color: #f1f1f1;
# }
# #T_b157e_row1_col1 {
#   background-color: #42425b;
#   color: #f1f1f1;
# }
# #T_b157e_row2_col0 {
#   background-color: #7f909f;
#   color: #f1f1f1;
# }
# #T_b157e_row2_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b157e_row3_col0 {
#   background-color: #343449;
#   color: #f1f1f1;
# }
# #T_b157e_row3_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b157e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b157e_level0_col0" class="col_heading level0 col0" >GaussianNB</th>
#       <th id="T_b157e_level0_col1" class="col_heading level0 col1" >LogisticRegression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Data akurasi untuk masing-masing model
model_names = [
    "Logistic Regression",
    "Naive Bayes"
]

# Akurasi prediksi model
model_accuracies = [
    accuracy_score(y_test, y_pred_logreg),
    accuracy_score(y_test, y_pred_g)
]

# Plotting bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(model_names, model_accuracies, color='skyblue', edgecolor='black')

# Annotating bar values
for bar in bars:
    plt.text(
        bar.get_width() + 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{bar.get_width():.2f}",
        va='center'
    )

# Adding titles and labels
plt.title("Model Comparison: Accuracy Scores", fontsize=14)
plt.xlabel("Accuracy", fontsize=12)
plt.ylabel("Models", fontsize=12)
plt.xlim(0, 1)
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Show plot
plt.tight_layout()
plt.show()
